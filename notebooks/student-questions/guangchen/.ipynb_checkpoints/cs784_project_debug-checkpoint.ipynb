# %%
import sys
sys.path.append('/Users/pradap/Documents/Research/Python-Package/enrique/')

# %%
# %load_ext autotime

# %%
import magellan as mg
# Out:
# DEBUG:Cloud:Log file (/Users/pradap/.picloud/cloud.log) opened

# %%
mg.init_jvm()
# Out:
# True

# %%
path_A = 'imdbClean.csv'
path_B = 'tmdClean.csv'

# read table A; table A has 'ID as the key attribute
A = mg.read_csv(path_A, key='ID')
B = mg.read_csv(path_B, key='ID')

# %%
# Read in I feature vector: director
I = mg.read_csv('train_set_director.csv', ltable=A, rtable=B)
# Out:
# time: 4.86 ms

# %%
I.head()
# Out:
#    _id  ltable.ID  rtable.ID  director_director_jac_qgm_3_qgm_3  \
# 0   94        488       1108                           0.900000
# 1  350       2594       2403                           0.150000
# 2   42        223        316                           0.909091
# 3  387       2940       2108                           0.941176
# 4   91        479        510                           0.916667
#
#    director_director_cos_dlm_dc0_dlm_dc0  \
# 0                                    1.0
# 1                                    0.5
# 2                                    1.0
# 3                                    1.0
# 4                                    1.0
#
#    director_director_jac_dlm_dc0_dlm_dc0  director_director_mel  \
# 0                               1.000000               1.000000
# 1                               0.333333               0.416667
# 2                               1.000000               1.000000
# 3                               1.000000               1.000000
# 4                               1.000000               1.000000
#
#    director_director_lev  director_director_nmw  director_director_sw  \
# 0               0.916667               1.000000              1.000000
# 1               0.357143               0.642857              0.416667
# 2               0.923077               1.000000              1.000000
# 3               0.947368               1.000000              1.000000
# 4               0.928571               1.000000              1.000000
#
#    director_director_swg  gold_label
# 0               1.000000           1
# 1               0.416667           0
# 2               1.000000           1
# 3               1.000000           1
# 4               1.000000           0
# time: 23.4 ms

# %%
# debug lg
lg = mg.LogRegMatcher()
# Out:
# time: 1.26 ms

# %%
# spliting data into U and V
dic = mg.train_test_split(I, train_proportion=0.7)
U = dic['train']
V = dic['test']
# Out:
# time: 7.64 ms

# %%
# train lg using U
lg.fit(table = U, exclude_attrs = ['_id', 'ltable.ID', 'rtable.ID', 'gold_label'],
                             target_attr = 'gold_label')
# Out:
# time: 10.5 ms

# %%
# predict on V
P5 = lg.predict(table = V, exclude_attrs = ['_id', 'ltable.ID', 'rtable.ID', 'gold_label'],
                             target_attr = 'predicted_label', append = True, inplace= False)
# Out:
# time: 10.5 ms

# %%
P5.head()
# Out:
#    _id  ltable.ID  rtable.ID  director_director_jac_qgm_3_qgm_3  \
# 0  330       2322       1852                           0.075000
# 1  101        533       1531                           0.160000
# 2   69        357        159                           0.916667
# 3  307       2159       1544                           0.888889
# 4  310       2171       1421                           0.875000
#
#    director_director_cos_dlm_dc0_dlm_dc0  \
# 0                               0.353553
# 1                               0.408248
# 2                               1.000000
# 3                               1.000000
# 4                               1.000000
#
#    director_director_jac_dlm_dc0_dlm_dc0  director_director_mel  \
# 0                                   0.20               0.371429
# 1                                   0.25               0.461538
# 2                                   1.00               1.000000
# 3                                   1.00               1.000000
# 4                                   1.00               1.000000
#
#    director_director_lev  director_director_nmw  director_director_sw  \
# 0               0.242424               0.546875              0.357143
# 1               0.421053               0.578947              0.461538
# 2               0.928571               1.000000              1.000000
# 3               0.909091               1.000000              1.000000
# 4               0.900000               1.000000              1.000000
#
#    director_director_swg  gold_label  predicted_label
# 0               0.400000           0                0
# 1               0.492308           0                0
# 2               1.000000           1                1
# 3               1.000000           1                1
# 4               1.000000           1                1
# time: 22.7 ms

# %%
# evaluation on predictions
eval_summary5 = mg.eval_matches(P5, 'gold_label', 'predicted_label')
# Out:
# time: 11.3 ms

# %%
mg.print_eval_summary(eval_summary5)
# Out:
# Precision : 93.55% (58/62)
# Recall : 98.31% (58/59)
# F1 : 95.87%
# False positives : 4 (out of 62 positive predictions)
# False negatives : 1 (out of 22 negative predictions)
# time: 1.06 ms

# %%
for p in eval_summary5:
    print p + ': ' + str(eval_summary5[p])
# Out:
# prec_numerator: 58.0
# prec_denominator: 62.0
# precision: 0.935483870968
# recall_numerator: 58.0
# recall_denominator: 59.0
# recall: 0.983050847458
# f1: 0.95867768595
# pred_pos_num: 62.0
# false_pos_num: 4.0
# false_pos_ls: [(106.0, 224.0), (305.0, 958.0), (106.0, 117.0), (479.0, 510.0)]
# pred_neg_num: 22.0
# false_neg_num: 1.0
# false_neg_ls: [(171.0, 63.0)]
# time: 1.37 ms

# %%
# write vector table U and V out
U.to_csv('vector_table_U.csv')
V.to_csv('vector_table_V.csv')
# Out:
# True

# %%
P5
# Out:
#     _id  ltable.ID  rtable.ID  director_director_jac_qgm_3_qgm_3  \
# 0   366       2768       2352                           0.411765
# 1   264       1738       2167                           0.285714
# 2   199       1143        509                           0.772727
# 3   331       2328        701                           0.875000
# 4    41        218        427                           0.928571
# 5   297       2023       1852                           0.923077
# 6   154        839       1595                           0.937500
# 7   145        781       1347                           0.923077
# 8     6         51         24                           0.888889
# 9    73        391       1828                           0.875000
# 10  152        828       1626                           0.916667
# 11  330       2322       1852                           0.075000
# 12  137        758        102                           0.916667
# 13    0          1          1                           0.909091
# 14  237       1480        958                           0.235294
# 15  213       1292       1269                           0.269231
# 16  365       2762       2700                           0.923077
# 17  261       1707        242                           0.800000
# 18  142        776       1531                           0.173913
# 19  172        942        574                           0.923077
# 20  370       2801        338                           0.200000
# 21  290       1936        144                           0.250000
# 22  392       2967       1847                           0.923077
# 23    8         51       1574                           0.235294
# 24  250       1594       1824                           0.085714
# 25  196       1141        153                           0.200000
# 26  380       2876        363                           0.142857
# 27  234       1464       2193                           0.684211
# 28  248       1590        917                           0.909091
# 29  323       2261        760                           0.260870
# ..  ...        ...        ...                                ...
# 54  379       2861       2144                           0.933333
# 55  239       1489        681                           0.750000
# 56   50        248       1893                           0.181818
# 57   45        229       1293                           0.200000
# 58   13         76       1720                           0.416667
# 59   15         83       1845                           0.181818
# 60  116        663        211                           0.937500
# 61  202       1150        435                           0.923077
# 62  101        533       1531                           0.160000
# 63  134        754       1584                           0.909091
# 64  240       1500        651                           0.928571
# 65  350       2594       2403                           0.150000
# 66  132        736       1483                           0.933333
# 67  352       2602        792                           0.318182
# 68  244       1562        699                           0.814815
# 69  222       1346       1683                           0.928571
# 70  225       1388       2620                           0.800000
# 71  193       1131       1301                           0.909091
# 72   64        323        151                           0.352941
# 73  349       2590       1302                           0.900000
# 74  173        951        485                           0.181818
# 75  136        757        832                           0.888889
# 76  371       2806       1438                           0.928571
# 77  159        861        203                           0.916667
# 78  190       1105       1574                           0.263158
# 79  363       2723       1357                           0.208333
# 80  307       2159       1544                           0.888889
# 81  206       1226        655                           0.937500
# 82  251       1600       1980                           0.900000
# 83   32        171         63                           0.714286
#
#     director_director_cos_dlm_dc0_dlm_dc0  \
# 0                                0.707107
# 1                                0.500000
# 2                                0.666667
# 3                                1.000000
# 4                                1.000000
# 5                                1.000000
# 6                                1.000000
# 7                                1.000000
# 8                                1.000000
# 9                                1.000000
# 10                               1.000000
# 11                               0.353553
# 12                               1.000000
# 13                               1.000000
# 14                               0.500000
# 15                               0.500000
# 16                               1.000000
# 17                               0.577350
# 18                               0.408248
# 19                               1.000000
# 20                               0.500000
# 21                               0.500000
# 22                               1.000000
# 23                               0.500000
# 24                               0.288675
# 25                               0.408248
# 26                               0.353553
# 27                               0.577350
# 28                               1.000000
# 29                               0.500000
# ..                                    ...
# 54                               1.000000
# 55                               0.577350
# 56                               0.500000
# 57                               0.500000
# 58                               0.500000
# 59                               0.408248
# 60                               1.000000
# 61                               1.000000
# 62                               0.408248
# 63                               1.000000
# 64                               1.000000
# 65                               0.500000
# 66                               1.000000
# 67                               0.500000
# 68                               0.577350
# 69                               1.000000
# 70                               0.577350
# 71                               1.000000
# 72                               0.500000
# 73                               1.000000
# 74                               0.316228
# 75                               1.000000
# 76                               1.000000
# 77                               1.000000
# 78                               0.500000
# 79                               0.500000
# 80                               1.000000
# 81                               1.000000
# 82                               1.000000
# 83                               0.577350
#
#     director_director_jac_dlm_dc0_dlm_dc0  director_director_mel  \
# 0                                0.500000               1.000000
# 1                                0.333333               0.777778
# 2                                0.500000               0.960000
# 3                                1.000000               1.000000
# 4                                1.000000               1.000000
# 5                                1.000000               1.000000
# 6                                1.000000               1.000000
# 7                                1.000000               1.000000
# 8                                1.000000               1.000000
# 9                                1.000000               1.000000
# 10                               1.000000               1.000000
# 11                               0.200000               0.371429
# 12                               1.000000               1.000000
# 13                               1.000000               1.000000
# 14                               0.333333               0.545455
# 15                               0.333333               0.500000
# 16                               1.000000               1.000000
# 17                               0.400000               0.964286
# 18                               0.250000               0.545455
# 19                               1.000000               1.000000
# 20                               0.333333               0.566667
# 21                               0.333333               0.600000
# 22                               1.000000               1.000000
# 23                               0.333333               0.700000
# 24                               0.166667               0.312500
# 25                               0.250000               0.545455
# 26                               0.200000               0.581818
# 27                               0.400000               0.950000
# 28                               1.000000               1.000000
# 29                               0.333333               0.614286
# ..                                    ...                    ...
# 54                               1.000000               1.000000
# 55                               0.400000               0.965517
# 56                               0.333333               0.461538
# 57                               0.333333               0.500000
# 58                               0.333333               0.741176
# 59                               0.250000               0.545455
# 60                               1.000000               1.000000
# 61                               1.000000               1.000000
# 62                               0.250000               0.461538
# 63                               1.000000               1.000000
# 64                               1.000000               1.000000
# 65                               0.333333               0.416667
# 66                               1.000000               1.000000
# 67                               0.333333               0.685714
# 68                               0.400000               0.952381
# 69                               1.000000               1.000000
# 70                               0.400000               0.965517
# 71                               1.000000               1.000000
# 72                               0.333333               0.615385
# 73                               1.000000               1.000000
# 74                               0.166667               0.571429
# 75                               1.000000               1.000000
# 76                               1.000000               1.000000
# 77                               1.000000               1.000000
# 78                               0.333333               0.723077
# 79                               0.333333               0.538462
# 80                               1.000000               1.000000
# 81                               1.000000               1.000000
# 82                               1.000000               1.000000
# 83                               0.400000               0.565217
#
#     director_director_lev  director_director_nmw  director_director_sw  \
# 0                0.409091               0.619048              1.000000
# 1                0.538462               0.653846              0.666667
# 2                0.925926               0.961538              0.980000
# 3                0.900000               1.000000              1.000000
# 4                0.937500               1.000000              1.000000
# 5                0.933333               1.000000              1.000000
# 6                0.944444               1.000000              1.000000
# 7                0.933333               1.000000              1.000000
# 8                0.909091               1.000000              1.000000
# 9                0.900000               1.000000              1.000000
# 10               0.928571               1.000000              1.000000
# 11               0.242424               0.546875              0.357143
# 12               0.928571               1.000000              1.000000
# 13               0.923077               1.000000              1.000000
# 14               0.461538               0.692308              0.545455
# 15               0.473684               0.750000              0.500000
# 16               0.933333               1.000000              1.000000
# 17               0.933333               0.965517              0.982143
# 18               0.263158               0.500000              0.545455
# 19               0.933333               1.000000              1.000000
# 20               0.466667               0.666667              0.500000
# 21               0.384615               0.615385              0.600000
# 22               0.933333               1.000000              1.000000
# 23               0.428571               0.607143              0.600000
# 24               0.269231               0.520000              0.312500
# 25               0.411765               0.562500              0.545455
# 26               0.307692               0.540000              0.545455
# 27               0.909091               0.952381              0.975000
# 28               0.923077               1.000000              1.000000
# 29               0.388889               0.611111              0.571429
# ..                    ...                    ...                   ...
# 54               0.941176               1.000000              1.000000
# 55               0.935484               0.966667              0.982759
# 56               0.500000               0.687500              0.461538
# 57               0.454545               0.681818              0.500000
# 58               0.600000               0.750000              0.705882
# 59               0.368421               0.527778              0.545455
# 60               0.944444               1.000000              1.000000
# 61               0.933333               1.000000              1.000000
# 62               0.421053               0.578947              0.461538
# 63               0.923077               1.000000              1.000000
# 64               0.937500               1.000000              1.000000
# 65               0.357143               0.642857              0.416667
# 66               0.941176               1.000000              1.000000
# 67               0.473684               0.638889              0.642857
# 68               0.931034               0.954545              0.976190
# 69               0.937500               1.000000              1.000000
# 70               0.935484               0.966667              0.982759
# 71               0.923077               1.000000              1.000000
# 72               0.571429               0.785714              0.615385
# 73               0.916667               1.000000              1.000000
# 74               0.344828               0.642857              0.571429
# 75               0.909091               1.000000              1.000000
# 76               0.937500               1.000000              1.000000
# 77               0.928571               1.000000              1.000000
# 78               0.642857               0.821429              0.538462
# 79               0.368421               0.552632              0.538462
# 80               0.909091               1.000000              1.000000
# 81               0.944444               1.000000              1.000000
# 82               0.916667               1.000000              1.000000
# 83               0.480000               0.666667              0.565217
#
#     director_director_swg  gold_label  predicted_label
# 0                1.000000           1                0
# 1                0.777778           0                0
# 2                0.960000           1                1
# 3                1.000000           1                1
# 4                1.000000           1                1
# 5                1.000000           0                1
# 6                1.000000           1                1
# 7                1.000000           1                1
# 8                1.000000           1                1
# 9                1.000000           1                1
# 10               1.000000           1                1
# 11               0.400000           0                0
# 12               1.000000           0                1
# 13               1.000000           1                1
# 14               0.545455           0                0
# 15               0.511111           0                0
# 16               1.000000           1                1
# 17               0.964286           1                1
# 18               0.545455           0                0
# 19               1.000000           1                1
# 20               0.566667           0                0
# 21               0.600000           0                0
# 22               1.000000           1                1
# 23               0.700000           0                0
# 24               0.312500           0                0
# 25               0.545455           0                0
# 26               0.581818           0                0
# 27               0.950000           1                1
# 28               1.000000           1                1
# 29               0.614286           0                0
# ..                    ...         ...              ...
# 54               1.000000           1                1
# 55               0.965517           1                1
# 56               0.600000           0                0
# 57               0.580000           0                0
# 58               0.741176           0                0
# 59               0.545455           0                0
# 60               1.000000           1                1
# 61               1.000000           1                1
# 62               0.492308           0                0
# 63               1.000000           1                1
# 64               1.000000           1                1
# 65               0.416667           0                0
# 66               1.000000           1                1
# 67               0.685714           0                0
# 68               0.952381           1                1
# 69               1.000000           1                1
# 70               0.965517           0                1
# 71               1.000000           1                1
# 72               0.615385           0                0
# 73               1.000000           1                1
# 74               0.571429           0                0
# 75               1.000000           1                1
# 76               1.000000           1                1
# 77               1.000000           1                1
# 78               0.723077           0                0
# 79               0.538462           0                0
# 80               1.000000           1                1
# 81               1.000000           1                1
# 82               1.000000           1                1
# 83               0.565217           1                0
#
# [84 rows x 13 columns]

# %%
feat_table = mg.get_features_for_matching(A, B)
# Out:
# WARNING:magellan.feature.autofeaturegen:Magellan types: year type (str_bt_1w_5w) and year type (numeric) are different.If you want to set them to be same and generate features, update output from get_attr_types and use get_features command.

# %%
feat_table
# Out:
#                              feature_name left_attribute right_attribute  \
# 0                               ID_ID_exm             ID              ID
# 1                               ID_ID_anm             ID              ID
# 2                               ID_ID_lev             ID              ID
# 3             title_title_jac_qgm_3_qgm_3          title           title
# 4         title_title_cos_dlm_dc0_dlm_dc0          title           title
# 5         title_title_jac_dlm_dc0_dlm_dc0          title           title
# 6                         title_title_mel          title           title
# 7                         title_title_lev          title           title
# 8                         title_title_nmw          title           title
# 9                          title_title_sw          title           title
# 10                        title_title_swg          title           title
# 11      director_director_jac_qgm_3_qgm_3       director        director
# 12  director_director_cos_dlm_dc0_dlm_dc0       director        director
# 13  director_director_jac_dlm_dc0_dlm_dc0       director        director
# 14                  director_director_mel       director        director
# 15                  director_director_lev       director        director
# 16                  director_director_nmw       director        director
# 17                   director_director_sw       director        director
# 18                  director_director_swg       director        director
# 19          writer_writer_jac_qgm_3_qgm_3         writer          writer
# 20      writer_writer_cos_dlm_dc0_dlm_dc0         writer          writer
# 21      writer_writer_jac_dlm_dc0_dlm_dc0         writer          writer
# 22                      writer_writer_mel         writer          writer
# 23                      writer_writer_lev         writer          writer
# 24                      writer_writer_nmw         writer          writer
# 25                       writer_writer_sw         writer          writer
# 26                      writer_writer_swg         writer          writer
# 27            actor_actor_jac_qgm_3_qgm_3          actor           actor
# 28        actor_actor_cos_dlm_dc0_dlm_dc0          actor           actor
# 29                        actor_actor_mel          actor           actor
# 30                        actor_actor_lev          actor           actor
#
#    left_attr_tokenizer right_attr_tokenizer           simfunction  \
# 0                 None                 None           exact_match
# 1                 None                 None              abs_norm
# 2                 None                 None                   lev
# 3                qgm_3                qgm_3               jaccard
# 4              dlm_dc0              dlm_dc0                cosine
# 5              dlm_dc0              dlm_dc0               jaccard
# 6                 None                 None           monge_elkan
# 7                 None                 None                   lev
# 8                 None                 None      needleman_wunsch
# 9                 None                 None        smith_waterman
# 10                None                 None  smith_waterman_gotoh
# 11               qgm_3                qgm_3               jaccard
# 12             dlm_dc0              dlm_dc0                cosine
# 13             dlm_dc0              dlm_dc0               jaccard
# 14                None                 None           monge_elkan
# 15                None                 None                   lev
# 16                None                 None      needleman_wunsch
# 17                None                 None        smith_waterman
# 18                None                 None  smith_waterman_gotoh
# 19               qgm_3                qgm_3               jaccard
# 20             dlm_dc0              dlm_dc0                cosine
# 21             dlm_dc0              dlm_dc0               jaccard
# 22                None                 None           monge_elkan
# 23                None                 None                   lev
# 24                None                 None      needleman_wunsch
# 25                None                 None        smith_waterman
# 26                None                 None  smith_waterman_gotoh
# 27               qgm_3                qgm_3               jaccard
# 28             dlm_dc0              dlm_dc0                cosine
# 29                None                 None           monge_elkan
# 30                None                 None                   lev
#
#                                              function  \
# 0                 <function ID_ID_exm at 0x124c0c9b0>
# 1                 <function ID_ID_anm at 0x124c0c668>
# 2                 <function ID_ID_lev at 0x124c0caa0>
# 3   <function title_title_jac_qgm_3_qgm_3 at 0x124...
# 4   <function title_title_cos_dlm_dc0_dlm_dc0 at 0...
# 5   <function title_title_jac_dlm_dc0_dlm_dc0 at 0...
# 6           <function title_title_mel at 0x124c0c848>
# 7           <function title_title_lev at 0x124c0c6e0>
# 8           <function title_title_nmw at 0x124c0cc08>
# 9            <function title_title_sw at 0x124c0cde8>
# 10          <function title_title_swg at 0x124c0ce60>
# 11  <function director_director_jac_qgm_3_qgm_3 at...
# 12  <function director_director_cos_dlm_dc0_dlm_dc...
# 13  <function director_director_jac_dlm_dc0_dlm_dc...
# 14    <function director_director_mel at 0x123e1c0c8>
# 15    <function director_director_lev at 0x123e1c140>
# 16    <function director_director_nmw at 0x123e1c1b8>
# 17     <function director_director_sw at 0x123e1c230>
# 18    <function director_director_swg at 0x123e1c2a8>
# 19  <function writer_writer_jac_qgm_3_qgm_3 at 0x1...
# 20  <function writer_writer_cos_dlm_dc0_dlm_dc0 at...
# 21  <function writer_writer_jac_dlm_dc0_dlm_dc0 at...
# 22        <function writer_writer_mel at 0x123e1c488>
# 23        <function writer_writer_lev at 0x123e1c500>
# 24        <function writer_writer_nmw at 0x123e1c578>
# 25         <function writer_writer_sw at 0x123e1c5f0>
# 26        <function writer_writer_swg at 0x123e1c668>
# 27  <function actor_actor_jac_qgm_3_qgm_3 at 0x123...
# 28  <function actor_actor_cos_dlm_dc0_dlm_dc0 at 0...
# 29          <function actor_actor_mel at 0x123e1c7d0>
# 30          <function actor_actor_lev at 0x123e1c848>
#
#                                       function_source
# 0   from magellan.feature.simfunctions import *\nf...
# 1   from magellan.feature.simfunctions import *\nf...
# 2   from magellan.feature.simfunctions import *\nf...
# 3   from magellan.feature.simfunctions import *\nf...
# 4   from magellan.feature.simfunctions import *\nf...
# 5   from magellan.feature.simfunctions import *\nf...
# 6   from magellan.feature.simfunctions import *\nf...
# 7   from magellan.feature.simfunctions import *\nf...
# 8   from magellan.feature.simfunctions import *\nf...
# 9   from magellan.feature.simfunctions import *\nf...
# 10  from magellan.feature.simfunctions import *\nf...
# 11  from magellan.feature.simfunctions import *\nf...
# 12  from magellan.feature.simfunctions import *\nf...
# 13  from magellan.feature.simfunctions import *\nf...
# 14  from magellan.feature.simfunctions import *\nf...
# 15  from magellan.feature.simfunctions import *\nf...
# 16  from magellan.feature.simfunctions import *\nf...
# 17  from magellan.feature.simfunctions import *\nf...
# 18  from magellan.feature.simfunctions import *\nf...
# 19  from magellan.feature.simfunctions import *\nf...
# 20  from magellan.feature.simfunctions import *\nf...
# 21  from magellan.feature.simfunctions import *\nf...
# 22  from magellan.feature.simfunctions import *\nf...
# 23  from magellan.feature.simfunctions import *\nf...
# 24  from magellan.feature.simfunctions import *\nf...
# 25  from magellan.feature.simfunctions import *\nf...
# 26  from magellan.feature.simfunctions import *\nf...
# 27  from magellan.feature.simfunctions import *\nf...
# 28  from magellan.feature.simfunctions import *\nf...
# 29  from magellan.feature.simfunctions import *\nf...
# 30  from magellan.feature.simfunctions import *\nf...

# %%
# Add trigger - target false positives: use title related feature
neg_trigger = mg.MatchTrigger()
neg_trigger.add_cond_rule('title_title_jac_qgm_3_qgm_3(ltuple, rtuple) < 0.4', feat_table)
neg_trigger.add_cond_status(True)
neg_trigger.add_action(0)
# Out:
# True

# %%
# Apply trigger and then evaluate
# Apply trigger
Q = neg_trigger.execute(P5, 'predicted_label', inplace=False)
# Out:
# /Users/guangshanchen/anaconda/lib/python2.7/site-packages/pandas/core/index.py:805: FutureWarning: scalar indexers for index type Int64Index should be integers and not floating point
#   type(self).__name__),FutureWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-c1c9a5935651> in <module>()
#       1 # Apply trigger and then evaluate
#       2 # Apply trigger
# ----> 3 Q = neg_trigger.execute(P5, 'predicted_label', inplace=False)
#
# /Users/guangshanchen/anaconda/lib/python2.7/site-packages/Magellan-0.1-py2.7.egg/magellan/trigger/matchtrigger.pyc in execute(self, input_table, label_column, inplace)
#     155                 # get the value of block attribute from ltuple
#     156                 # t.ix[t.index.values[0], feature_names]
# --> 157                 l_row = l_tbl.ix[row[lid_idx]]
#     158                 # l_row = l_tbl.ix[row.ix[row.index.values[0], l_key]]
#     159                 # r_row = r_tbl.ix[row.ix[row.index.values[0], r_key]]
#
# /Users/guangshanchen/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#      68             return self._getitem_tuple(key)
#      69         else:
# ---> 70             return self._getitem_axis(key, axis=0)
#      71
#      72     def _get_label(self, label, axis=0):
#
# /Users/guangshanchen/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#     927                     return self._get_loc(key, axis=axis)
#     928
# --> 929             return self._get_label(key, axis=axis)
#     930
#     931     def _getitem_iterable(self, key, axis=0):
#
# /Users/guangshanchen/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _get_label(self, label, axis)
#      84             raise IndexingError('no slices here, handle elsewhere')
#      85
# ---> 86         return self.obj._xs(label, axis=axis)
#      87
#      88     def _get_loc(self, key, axis=0):
#
# /Users/guangshanchen/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in xs(self, key, axis, level, copy, drop_level)
#    1471                                                       drop_level=drop_level)
#    1472         else:
# -> 1473             loc = self.index.get_loc(key)
#    1474
#    1475             if isinstance(loc, np.ndarray):
#
# /Users/guangshanchen/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key, method)
#    1570         """
#    1571         if method is None:
# -> 1572             return self._engine.get_loc(_values_from_object(key))
#    1573
#    1574         indexer = self.get_indexer([key], method=method)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3824)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3665)()
#
# pandas/index.pyx in pandas.index.Int64Engine._check_type (pandas/index.c:7316)()
#
# KeyError: 1143.0

# %%
help(mg.MatchTrigger())
# Out:
# Help on MatchTrigger in module magellan.trigger.matchtrigger object:
#
# class MatchTrigger(__builtin__.object)
#  |  Class to patch output from Matchers.
#  |  Note:
#  |  This class is similar to BooleanRuleMatcher except that this class switches predictions.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |
#  |  add_action(self, value)
#  |      Add action if the condition evaluates to condition status (see add_cond_rule, add_cond_status)
#  |
#  |      Parameters
#  |      ----------
#  |      value : int (0/1). Value to be set if the condition evaluates to condition status
#  |
#  |      Returns
#  |      -------
#  |      status : boolean, returns True if the command was executed successfully.
#  |
#  |  add_cond_rule(self, conjunct_list, feature_table)
#  |      Add rule to match trigger
#  |
#  |      Parameters
#  |      ----------
#  |      conjunct_list : List of strings.
#  |       List of predicates as in ['title_title_lev(ltuple, rtuple) > 0.8', 'name_name_mel(ltuple, rtuple)' > 0.6]
#  |
#  |      feature_table : Pandas dataframe.
#  |        Feature table containing information about features.
#  |        see also:  get_features_for_blocking, get_features_from_matching, get_features
#  |
#  |      Returns
#  |      -------
#  |      status : boolean, return True if the command was executed successfully.
#  |
#  |  add_cond_status(self, status)
#  |      Add boolean status that the condition is expected to satisfy
#  |
#  |      Parameters
#  |      ----------
#  |      status : boolean, status that the user wants the condition to satisfy
#  |
#  |      Returns
#  |      -------
#  |      ret_status : boolean, returns True if the command was executed successfully.
#  |
#  |  apply_rules(self, ltuple, rtuple)
#  |
#  |  create_rule(self, conjunct_list, feature_table, name=None)
#  |
#  |  del_rule(self, rule_name)
#  |
#  |  execute(self, input_table, label_column, inplace=True)
#  |      Execute trigger
#  |
#  |      Parameters
#  |      ----------
#  |      input_table : MTable, on which trigger must be applied
#  |      label_column : String, label attribute name
#  |      inplace : boolean, whether the updation should be done inplace. Default value is set to True.
#  |
#  |  get_function_str(self, name, conjunct_list)
#  |
#  |  get_rule(self, rule_name)
#  |
#  |  get_rule_names(self)
#  |
#  |  view_rule(self, rule_name)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
