# %%
import sys
sys.path.append('/Users/pradap/Documents/Research/Python-Package/enrique/')

# %%
import magellan as mg
import numpy as np

# %%
from magellan import MTable

# %%
# sample one table using random sampling
def sample_table(table, size, replace=False):
    """
    Sample MTable
    Parameters
    ----------
    table : MTable, input table to be sampled
    size : int, number of samples
    replace : boolean, whether sampling should be done with replacement.
            By default, it is set to False.
    Returns
    -------
    sampled_table: MTable, sampled table
    """
    if len(table) == 0:
        raise AttributeError('size of table is 0')
    if len(table) < size:
        raise AttributeError('sample size is larger than input table size')

    s_indices = np.random.choice(len(table), size, replace=replace)
    # sort the indices - just to have an order
    s_indices = sorted(s_indices)
    sampled_table =  table.iloc[list(s_indices)]
    #print sampled_table.properties
    sampled_table = MTable(sampled_table, key=table.get_key())
    sampled_table.properties = table.properties
    return sampled_table

# %%
# Blocking
## plan : 
### A, B -----------overlap blocking 
#(title)-----------------------------> candset  |
### A, B ------------rule-based-blocking(title & director)
# ----------------> candset |----union--->candset


A = mg.read_csv('tableA.csv', key='ID')
B = mg.read_csv('tableB.csv', key='ID')
A1 = sample_table(A, 500) 
B1 = sample_table(B, 500)
ob = mg.OverlapBlocker()
ab = mg.AttrEquivalenceBlocker()

# %%
C = ab.block_tables(A1, B1, 'Title', 'Title', 'Title', 'Title')
C.head()
# Out:
#    _id  ltable.ID  rtable.ID ltable.Title rtable.Title
# 0    0         40         39    Barricade    Barricade
# 1    1        139        130    Extracted    Extracted
# 2    2        321        297      Cop Out      Cop Out
# 3    3        347        322      Flipped      Flipped
# 4    4        384        353       Kaboom       Kaboom

# %%
D = ob.block_tables(A1, B1, 'Title', 'Title', 
                    l_output_attrs=['Title'], r_output_attrs=['Title'])
D.head()
# Out:
# 0%                          100%
# [##############################] | ETA[sec]: 0.000
# Total time elapsed: 1.800 sec
#    _id  ltable.ID rtable.ID                 ltable.Title  \
# 0    0          8      2606                 About Cherry
# 1    1          8      2721                 About Cherry
# 2    2          9       180  Abraham Lincoln vs. Zombies
# 3    3          9       525  Abraham Lincoln vs. Zombies
# 4    4          9       550  Abraham Lincoln vs. Zombies
#
#                    rtable.Title
# 0        Much Ado About Nothing
# 1    10 Things I Hate About You
# 2                       Lincoln
# 3  Hoodwinked Too! Hood vs Evil
# 4            The Lincoln Lawyer

# %%
feature_table = mg.get_features_for_blocking(A1, B1)
#feature_table
# Out:
# WARNING:magellan.feature.autofeaturegen:Rating type and Rating type are different
# WARNING:magellan.feature.autofeaturegen:Cast type and Cast type are different
# WARNING:magellan.feature.autofeaturegen:Genre type and Genre type are different
# WARNING:magellan.feature.autofeaturegen:ContentRating type and ContentRating type are different

# %%
rb = mg.RuleBasedBlocker()
rb.add_rule(['Title_Title_lev(ltuple,rtuple) < 0.8',
             'Director_Director_nmw(ltuple,rtuple) < 0.8'], feature_table)
# Out:
# True

# %%
mg.init_jvm() #Do we even need this? Doesn't work on my machine.
# Pradap --- if doesn't work let me know what happens and error msg if any.
# Out:
# WARNING:magellan.utils.helperfunctions:JVM is already running
# True

# %%
#WORKING PERFECTLY! EDIT DISTANCE!
E = rb.block_tables(A1, B1, 
                    l_output_attrs=['Title'], r_output_attrs=['Title'])
E.head()
# Out:
# 0%                          100%
# [##############################] | ETA[sec]: 0.000
# Total time elapsed: 37.313 sec
#    _id  ltable.ID  rtable.ID                 ltable.Title  \
# 0    0          8        159                 About Cherry
# 1    1          8       1031                 About Cherry
# 2    2          8       1421                 About Cherry
# 3    3          8       1871                 About Cherry
# 4    4          9        159  Abraham Lincoln vs. Zombies
#
#                            rtable.Title
# 0  Comedy Dynamics Presents: Bill Hicks
# 1                       The Bounce Back
# 2                   Criminal Activities
# 3                 R5: All Day All Night
# 4  Comedy Dynamics Presents: Bill Hicks

# %%
def year_blocker_function(x, y):
    x_date = str(x['Year'])
    y_date = str(y['Year'])
    if(x_date=='NULL' or y_date=='NULL' or x_date == 'nan' 
       or y_date == 'nan'):
        return False #Since one of them is NULL, 
    we cannot block using this feature
    x_year = int(x_date.split('-')[0])
    y_year = int(y_date.split('-')[0])
    
    if(x_year > y_year + 1 or x_year < y_year - 1):
        return True #Block the tuples
    
    return False

bb = mg.BlackBoxBlocker()
bb.set_black_box_function(year_blocker_function)
# Out:
# True

# %%
# F = bb.block_tables(A, B, 
#                     l_output_attrs=['Title'], 
#                     r_output_attrs=['Title'])
# Out:
# 0%                          100%
# [                              ]

# %%
#F #NOW F will have all movie pairs that have 
# been released within one year of each other
#We need to apply this along with other blockers 
#to make it practical

# %%
G = mg.combine_block_outputs_via_union([D, E])
G.head()
# Out:
#    _id  ltable.ID  rtable.ID  ltable.Title  \
# 0    0          8        159  About Cherry
# 1    1          8       1031  About Cherry
# 2    2          8       1421  About Cherry
# 3    3          8       1871  About Cherry
# 4    4          8       2606  About Cherry
#
#                            rtable.Title
# 0  Comedy Dynamics Presents: Bill Hicks
# 1                       The Bounce Back
# 2                   Criminal Activities
# 3                 R5: All Day All Night
# 4                Much Ado About Nothing

# %%
 corres_var = [('ID','ID'),('Title','Title'),('Director','Director')]
 mg.debug_blocker(A, B, G, attr_corres=corres_var, output_size=200)
# Out:
# 0%                          100%
# [##############################] | ETA[sec]: 0.000
# Total time elapsed: 21.566 sec
#      _id  similarity  ltable.ID  rtable.ID               ltable.Title  \
# 0      0           1       2760       2426            Before Midnight
# 1      1           1       2762       2429        Beside Still Waters
# 2      2           1       2767       2434                    Big Sur
# 3      3           1       2770       2437                  Blackfish
# 4      4           1       2763       2430           Best Kept Secret
# 5      5           1       2768       2435            The Big Wedding
# 6      6           1       2769       2436             Black Nativity
# 7      7           1       2777       2444             The Book Thief
# 8      8           1       2791       2457                       CBGB
# 9      9           1       2764       2431       The Best Man Holiday
# 10    10           1       2765       2432   Beyond the Farthest Star
# 11    11           1       2773       2440               Blue Caprice
# 12    12           1       2774       2441               Blue Jasmine
# 13    13           1       2776       2443         The Book of Esther
# 14    14           1       2775       2442                  Blue Ruin
# 15    15           1       2779       2446           The Brass Teapot
# 16    16           1       2778       2445              Bounty Killer
# 17    17           1       2802       2465                 Concussion
# 27          Charlie Countryman               Fredrik Bond
# 28        The Company You Keep             Robert Redford
# 29                 Enough Said          Nicole Holofcener
# ..                         ...                        ...
# 170              Super Size Me            Morgan Spurlock
# 171               She Wants Me              Rob Margolies
# 172               The Smurfs 2               Raja Gosnell
# 173              Short Term 12      Destin Daniel Cretton
# 174                  A Teacher              Hannah Fidell
# 175     A Good Day To Die Hard                 John Moore
# 176               Saving Santa                Leon Joosen
# 177                       Epic                Chris Wedge
# 178         Inequality For All            Jacob Kornbluth
# 179         Out of the Furnace               Scott Cooper
# 180             Saving Lincoln            Salvador Litvak
# 181            The Lone Ranger             Gore Verbinski
# 182  Spirit Of The Marathon II                 Jon Dunham
# 183    Star Trek Into Darkness                J.J. Abrams
# 184           Saving Mr. Banks           John Lee Hancock
# 185                Little Feet         Alexandre Rockwell
# 186             White Reindeer                 Zach Clark
# 187                   Salinger              Shane Salerno
# 188                   McCanick             Josh C. Waller
# 189        The Kings of Summer        Jordan Vogt-Roberts
# 190                  Liars All             Brian Brightly
# 191              Stand Up Guys             Fisher Stevens
# 192               Side Effects          Steven Soderbergh
# 193        Monsters University                Dan Scanlon
# 194             Killing Season        Mark Steven Johnson
# 195       The Saratov Approach              Garrett Batty
# 196                     Parker            Taylor Hackford
# 197               Man of Steel                Zack Snyder
# 198                  The Purge             James DeMonaco
# 199                Warm Bodies            Jonathan Levine
#
#                rtable.Director
# 0            Richard Linklater
# 1                 Chris Lowell
# 2               Michael Polish
# 3       Gabriela Cowperthwaite
# 4                Samantha Buck
# 5               Justin Zackham
# 6                 Kasi Lemmons
# 7               Brian Percival
# 8               Randall Miller
# 9               Malcolm D. Lee
# 10             Andrew Librizzi
# 11             Alexandre Moors
# 12                 Woody Allen
# 13            David A.R. White
# 14             Jeremy Saulnier
# 15                Ramaa Mosley
# 16                 Henry Saine
# 17             Peter Landesman
# 18               Andrew Weiner
# 19               Sofia Coppola
# 20   Linda Bloodworth-Thomason
# 21               Drake Doremus
# 22            Don Michael Paul
# 23             Paul Greengrass
# 24                  Rick Beyer
# 25             Ruben Fleischer
# 26               Pierre Coffin
# 27                Fredrik Bond
# 28              Robert Redford
# 29           Nicole Holofcener
# ..                         ...
# 170            Morgan Spurlock
# 171              Rob Margolies
# 172               Raja Gosnell
# 173      Destin Daniel Cretton
# 174              Hannah Fidell
# 175                 John Moore
# 176                Leon Joosen
# 177                Chris Wedge
# 178            Jacob Kornbluth
# 179               Scott Cooper
# 180            Salvador Litvak
# 181             Gore Verbinski
# 182                 Jon Dunham
# 183                J.J. Abrams
# 184           John Lee Hancock
# 185         Alexandre Rockwell
# 186                 Zach Clark
# 187              Shane Salerno
# 188             Josh C. Waller
# 189        Jordan Vogt-Roberts
# 190             Brian Brightly
# 191             Fisher Stevens
# 192          Steven Soderbergh
# 193                Dan Scanlon
# 194        Mark Steven Johnson
# 195              Garrett Batty
# 196            Taylor Hackford
# 197                Zack Snyder
# 198             James DeMonaco
# 199            Jonathan Levine
#
# [200 rows x 8 columns]
