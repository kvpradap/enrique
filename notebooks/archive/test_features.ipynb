# %%
import sys
sys.path.append('/scratch/pradap/python-work/enrique/')

# %%
# %install_ext https://raw.github.com/cpcloud/ipython-autotime/master/autotime.py
# Out:
# Installed autotime.py. To use it, type:
#   %load_ext autotime

# %%
# %load_ext autotime

# %%
import magellan as mg
# Out:
# time: 462 ms

# %%
A = mg.load_dataset('table_A')
# Out:
# time: 2.61 ms

# %%
B = mg.load_dataset('table_B')
# Out:
# time: 2.07 ms

# %%
mg.init_jvm()
# Out:
# True
# time: 60.3 ms

# %%
# block using zipcode
ab = mg.AttrEquivalenceBlocker()
C = ab.block_tables(A, B, 'zipcode', 'zipcode', l_output_attrs=['name', 'hourly_wage', 'zipcode'],
                    r_output_attrs=['name', 'hourly_wage', 'zipcode'])
# Out:
# time: 8.48 ms

# %%
C
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_id</th>
#       <th>ltable.ID</th>
#       <th>rtable.ID</th>
#       <th>ltable.name</th>
#       <th>ltable.hourly_wage</th>
#       <th>ltable.zipcode</th>
#       <th>rtable.name</th>
#       <th>rtable.hourly_wage</th>
#       <th>rtable.zipcode</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>a1</td>
#       <td>b1</td>
#       <td>Kevin Smith</td>
#       <td>30.0</td>
#       <td>94107</td>
#       <td>Mark Levene</td>
#       <td>29.5</td>
#       <td>94107</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>a1</td>
#       <td>b2</td>
#       <td>Kevin Smith</td>
#       <td>30.0</td>
#       <td>94107</td>
#       <td>Bill Bridge</td>
#       <td>32.0</td>
#       <td>94107</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>a1</td>
#       <td>b6</td>
#       <td>Kevin Smith</td>
#       <td>30.0</td>
#       <td>94107</td>
#       <td>Michael Brodie</td>
#       <td>32.5</td>
#       <td>94107</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>a3</td>
#       <td>b1</td>
#       <td>William Bridge</td>
#       <td>32.0</td>
#       <td>94107</td>
#       <td>Mark Levene</td>
#       <td>29.5</td>
#       <td>94107</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>a3</td>
#       <td>b2</td>
#       <td>William Bridge</td>
#       <td>32.0</td>
#       <td>94107</td>
#       <td>Bill Bridge</td>
#       <td>32.0</td>
#       <td>94107</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>a3</td>
#       <td>b6</td>
#       <td>William Bridge</td>
#       <td>32.0</td>
#       <td>94107</td>
#       <td>Michael Brodie</td>
#       <td>32.5</td>
#       <td>94107</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>a2</td>
#       <td>b3</td>
#       <td>Michael Franklin</td>
#       <td>27.5</td>
#       <td>94122</td>
#       <td>Mike Franklin</td>
#       <td>27.5</td>
#       <td>94122</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>a2</td>
#       <td>b4</td>
#       <td>Michael Franklin</td>
#       <td>27.5</td>
#       <td>94122</td>
#       <td>Joseph Kuan</td>
#       <td>26.0</td>
#       <td>94122</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>a2</td>
#       <td>b5</td>
#       <td>Michael Franklin</td>
#       <td>27.5</td>
#       <td>94122</td>
#       <td>Alfons Kemper</td>
#       <td>35.0</td>
#       <td>94122</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>a4</td>
#       <td>b3</td>
#       <td>Binto George</td>
#       <td>32.5</td>
#       <td>94122</td>
#       <td>Mike Franklin</td>
#       <td>27.5</td>
#       <td>94122</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>10</td>
#       <td>a4</td>
#       <td>b4</td>
#       <td>Binto George</td>
#       <td>32.5</td>
#       <td>94122</td>
#       <td>Joseph Kuan</td>
#       <td>26.0</td>
#       <td>94122</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>11</td>
#       <td>a4</td>
#       <td>b5</td>
#       <td>Binto George</td>
#       <td>32.5</td>
#       <td>94122</td>
#       <td>Alfons Kemper</td>
#       <td>35.0</td>
#       <td>94122</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>12</td>
#       <td>a5</td>
#       <td>b3</td>
#       <td>Alphonse Kemper</td>
#       <td>35.0</td>
#       <td>94122</td>
#       <td>Mike Franklin</td>
#       <td>27.5</td>
#       <td>94122</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>13</td>
#       <td>a5</td>
#       <td>b4</td>
#       <td>Alphonse Kemper</td>
#       <td>35.0</td>
#       <td>94122</td>
#       <td>Joseph Kuan</td>
#       <td>26.0</td>
#       <td>94122</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>14</td>
#       <td>a5</td>
#       <td>b5</td>
#       <td>Alphonse Kemper</td>
#       <td>35.0</td>
#       <td>94122</td>
#       <td>Alfons Kemper</td>
#       <td>35.0</td>
#       <td>94122</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# time: 22.6 ms

# %%
feat_table = mg.get_features_for_blocking(A, B)
# Out:
# WARNING:magellan.feature.autofeaturegen:address type and address type are different
# [('ID_ID_lev', 'ID', 'ID', None, None, 'lev', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef ID_ID_lev(ltuple, rtuple):\n    return lev(ltuple["ID"], rtuple["ID"])'), ('ID_ID_jar', 'ID', 'ID', None, None, 'jaro', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef ID_ID_jar(ltuple, rtuple):\n    return jaro(ltuple["ID"], rtuple["ID"])'), ('ID_ID_jwn', 'ID', 'ID', None, None, 'jaro_winkler', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef ID_ID_jwn(ltuple, rtuple):\n    return jaro_winkler(ltuple["ID"], rtuple["ID"])'), ('ID_ID_sdx', 'ID', 'ID', None, None, 'soundex', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef ID_ID_sdx(ltuple, rtuple):\n    return soundex(ltuple["ID"], rtuple["ID"])'), ('ID_ID_exm', 'ID', 'ID', None, None, 'exact_match', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef ID_ID_exm(ltuple, rtuple):\n    return exact_match(ltuple["ID"], rtuple["ID"])'), ('ID_ID_jac_qgm_3_qgm_3', 'ID', 'ID', 'qgm_3', 'qgm_3', 'jaccard', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef ID_ID_jac_qgm_3_qgm_3(ltuple, rtuple):\n    return jaccard(qgm_3(ltuple["ID"]), qgm_3(rtuple["ID"])) ')]
# [('name_name_jac_qgm_3_qgm_3', 'name', 'name', 'qgm_3', 'qgm_3', 'jaccard', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef name_name_jac_qgm_3_qgm_3(ltuple, rtuple):\n    return jaccard(qgm_3(ltuple["name"]), qgm_3(rtuple["name"])) '), ('name_name_cos_dlm_dc0_dlm_dc0', 'name', 'name', 'dlm_dc0', 'dlm_dc0', 'cosine', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef name_name_cos_dlm_dc0_dlm_dc0(ltuple, rtuple):\n    return cosine(dlm_dc0(ltuple["name"]), dlm_dc0(rtuple["name"])) '), ('name_name_jac_dlm_dc0_dlm_dc0', 'name', 'name', 'dlm_dc0', 'dlm_dc0', 'jaccard', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef name_name_jac_dlm_dc0_dlm_dc0(ltuple, rtuple):\n    return jaccard(dlm_dc0(ltuple["name"]), dlm_dc0(rtuple["name"])) '), ('name_name_mel', 'name', 'name', None, None, 'monge_elkan', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef name_name_mel(ltuple, rtuple):\n    return monge_elkan(ltuple["name"], rtuple["name"])'), ('name_name_nmw', 'name', 'name', None, None, 'needleman_wunsch', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef name_name_nmw(ltuple, rtuple):\n    return needleman_wunsch(ltuple["name"], rtuple["name"])'), ('name_name_sw', 'name', 'name', None, None, 'smith_waterman', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef name_name_sw(ltuple, rtuple):\n    return smith_waterman(ltuple["name"], rtuple["name"])'), ('name_name_swg', 'name', 'name', None, None, 'smith_waterman_gotoh', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef name_name_swg(ltuple, rtuple):\n    return smith_waterman_gotoh(ltuple["name"], rtuple["name"])')]
# [('birth_year_birth_year_exm', 'birth_year', 'birth_year', None, None, 'exact_match', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef birth_year_birth_year_exm(ltuple, rtuple):\n    return exact_match(ltuple["birth_year"], rtuple["birth_year"])'), ('birth_year_birth_year_anm', 'birth_year', 'birth_year', None, None, 'abs_norm', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef birth_year_birth_year_anm(ltuple, rtuple):\n    return abs_norm(ltuple["birth_year"], rtuple["birth_year"])'), ('birth_year_birth_year_lev', 'birth_year', 'birth_year', None, None, 'lev', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef birth_year_birth_year_lev(ltuple, rtuple):\n    return lev(ltuple["birth_year"], rtuple["birth_year"])')]
# [('hourly_wage_hourly_wage_exm', 'hourly_wage', 'hourly_wage', None, None, 'exact_match', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef hourly_wage_hourly_wage_exm(ltuple, rtuple):\n    return exact_match(ltuple["hourly_wage"], rtuple["hourly_wage"])'), ('hourly_wage_hourly_wage_anm', 'hourly_wage', 'hourly_wage', None, None, 'abs_norm', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef hourly_wage_hourly_wage_anm(ltuple, rtuple):\n    return abs_norm(ltuple["hourly_wage"], rtuple["hourly_wage"])'), ('hourly_wage_hourly_wage_lev', 'hourly_wage', 'hourly_wage', None, None, 'lev', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef hourly_wage_hourly_wage_lev(ltuple, rtuple):\n    return lev(ltuple["hourly_wage"], rtuple["hourly_wage"])')]
# [('zipcode_zipcode_exm', 'zipcode', 'zipcode', None, None, 'exact_match', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef zipcode_zipcode_exm(ltuple, rtuple):\n    return exact_match(ltuple["zipcode"], rtuple["zipcode"])'), ('zipcode_zipcode_anm', 'zipcode', 'zipcode', None, None, 'abs_norm', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef zipcode_zipcode_anm(ltuple, rtuple):\n    return abs_norm(ltuple["zipcode"], rtuple["zipcode"])'), ('zipcode_zipcode_lev', 'zipcode', 'zipcode', None, None, 'lev', 'from magellan.feature.simfunctions import *\nfrom magellan.feature.tokenizers import *\ndef zipcode_zipcode_lev(ltuple, rtuple):\n    return lev(ltuple["zipcode"], rtuple["zipcode"])')]
# time: 10.4 ms

# %%
feat_table
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>feature_name</th>
#       <th>left_attribute</th>
#       <th>right_attribute</th>
#       <th>left_attr_tokenizer</th>
#       <th>right_attr_tokenizer</th>
#       <th>simfunction</th>
#       <th>function</th>
#       <th>function_source</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ID_ID_lev</td>
#       <td>ID</td>
#       <td>ID</td>
#       <td>None</td>
#       <td>None</td>
#       <td>lev</td>
#       <td>&lt;function ID_ID_lev at 0x7f14d294c140&gt;</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>ID_ID_jar</td>
#       <td>ID</td>
#       <td>ID</td>
#       <td>None</td>
#       <td>None</td>
#       <td>jaro</td>
#       <td>&lt;function ID_ID_jar at 0x7f14d294c1b8&gt;</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>ID_ID_jwn</td>
#       <td>ID</td>
#       <td>ID</td>
#       <td>None</td>
#       <td>None</td>
#       <td>jaro_winkler</td>
#       <td>&lt;function ID_ID_jwn at 0x7f14d294c050&gt;</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>ID_ID_sdx</td>
#       <td>ID</td>
#       <td>ID</td>
#       <td>None</td>
#       <td>None</td>
#       <td>soundex</td>
#       <td>&lt;function ID_ID_sdx at 0x7f14d294c320&gt;</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>ID_ID_exm</td>
#       <td>ID</td>
#       <td>ID</td>
#       <td>None</td>
#       <td>None</td>
#       <td>exact_match</td>
#       <td>&lt;function ID_ID_exm at 0x7f14d294c488&gt;</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>ID_ID_jac_qgm_3_qgm_3</td>
#       <td>ID</td>
#       <td>ID</td>
#       <td>qgm_3</td>
#       <td>qgm_3</td>
#       <td>jaccard</td>
#       <td>&lt;function ID_ID_jac_qgm_3_qgm_3 at 0x7f14d294c...</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>name_name_jac_qgm_3_qgm_3</td>
#       <td>name</td>
#       <td>name</td>
#       <td>qgm_3</td>
#       <td>qgm_3</td>
#       <td>jaccard</td>
#       <td>&lt;function name_name_jac_qgm_3_qgm_3 at 0x7f14d...</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>name_name_cos_dlm_dc0_dlm_dc0</td>
#       <td>name</td>
#       <td>name</td>
#       <td>dlm_dc0</td>
#       <td>dlm_dc0</td>
#       <td>cosine</td>
#       <td>&lt;function name_name_cos_dlm_dc0_dlm_dc0 at 0x7...</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>name_name_jac_dlm_dc0_dlm_dc0</td>
#       <td>name</td>
#       <td>name</td>
#       <td>dlm_dc0</td>
#       <td>dlm_dc0</td>
#       <td>jaccard</td>
#       <td>&lt;function name_name_jac_dlm_dc0_dlm_dc0 at 0x7...</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>name_name_mel</td>
#       <td>name</td>
#       <td>name</td>
#       <td>None</td>
#       <td>None</td>
#       <td>monge_elkan</td>
#       <td>&lt;function name_name_mel at 0x7f14d294c6e0&gt;</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>name_name_nmw</td>
#       <td>name</td>
#       <td>name</td>
#       <td>None</td>
#       <td>None</td>
#       <td>needleman_wunsch</td>
#       <td>&lt;function name_name_nmw at 0x7f14d294c758&gt;</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>name_name_sw</td>
#       <td>name</td>
#       <td>name</td>
#       <td>None</td>
#       <td>None</td>
#       <td>smith_waterman</td>
#       <td>&lt;function name_name_sw at 0x7f14d294c7d0&gt;</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>name_name_swg</td>
#       <td>name</td>
#       <td>name</td>
#       <td>None</td>
#       <td>None</td>
#       <td>smith_waterman_gotoh</td>
#       <td>&lt;function name_name_swg at 0x7f14d294c848&gt;</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>birth_year_birth_year_exm</td>
#       <td>birth_year</td>
#       <td>birth_year</td>
#       <td>None</td>
#       <td>None</td>
#       <td>exact_match</td>
#       <td>&lt;function birth_year_birth_year_exm at 0x7f14d...</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>birth_year_birth_year_anm</td>
#       <td>birth_year</td>
#       <td>birth_year</td>
#       <td>None</td>
#       <td>None</td>
#       <td>abs_norm</td>
#       <td>&lt;function birth_year_birth_year_anm at 0x7f14d...</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>birth_year_birth_year_lev</td>
#       <td>birth_year</td>
#       <td>birth_year</td>
#       <td>None</td>
#       <td>None</td>
#       <td>lev</td>
#       <td>&lt;function birth_year_birth_year_lev at 0x7f14d...</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>hourly_wage_hourly_wage_exm</td>
#       <td>hourly_wage</td>
#       <td>hourly_wage</td>
#       <td>None</td>
#       <td>None</td>
#       <td>exact_match</td>
#       <td>&lt;function hourly_wage_hourly_wage_exm at 0x7f1...</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>hourly_wage_hourly_wage_anm</td>
#       <td>hourly_wage</td>
#       <td>hourly_wage</td>
#       <td>None</td>
#       <td>None</td>
#       <td>abs_norm</td>
#       <td>&lt;function hourly_wage_hourly_wage_anm at 0x7f1...</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>hourly_wage_hourly_wage_lev</td>
#       <td>hourly_wage</td>
#       <td>hourly_wage</td>
#       <td>None</td>
#       <td>None</td>
#       <td>lev</td>
#       <td>&lt;function hourly_wage_hourly_wage_lev at 0x7f1...</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>zipcode_zipcode_exm</td>
#       <td>zipcode</td>
#       <td>zipcode</td>
#       <td>None</td>
#       <td>None</td>
#       <td>exact_match</td>
#       <td>&lt;function zipcode_zipcode_exm at 0x7f14d294cb90&gt;</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>zipcode_zipcode_anm</td>
#       <td>zipcode</td>
#       <td>zipcode</td>
#       <td>None</td>
#       <td>None</td>
#       <td>abs_norm</td>
#       <td>&lt;function zipcode_zipcode_anm at 0x7f14d294cc08&gt;</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>zipcode_zipcode_lev</td>
#       <td>zipcode</td>
#       <td>zipcode</td>
#       <td>None</td>
#       <td>None</td>
#       <td>lev</td>
#       <td>&lt;function zipcode_zipcode_lev at 0x7f14d294cc80&gt;</td>
#       <td>from magellan.feature.simfunctions import *\nf...</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# time: 30.5 ms

# %%
c_prime = mg.extract_feat_vecs(C, attrs_before=['ltable.name', 'rtable.name'], feat_table=feat_table)
# Out:
# time: 191 ms

# %%
c_prime
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_id</th>
#       <th>ltable.ID</th>
#       <th>rtable.ID</th>
#       <th>ltable.name</th>
#       <th>rtable.name</th>
#       <th>ID_ID_lev</th>
#       <th>ID_ID_jar</th>
#       <th>ID_ID_jwn</th>
#       <th>ID_ID_sdx</th>
#       <th>ID_ID_exm</th>
#       <th>...</th>
#       <th>name_name_swg</th>
#       <th>birth_year_birth_year_exm</th>
#       <th>birth_year_birth_year_anm</th>
#       <th>birth_year_birth_year_lev</th>
#       <th>hourly_wage_hourly_wage_exm</th>
#       <th>hourly_wage_hourly_wage_anm</th>
#       <th>hourly_wage_hourly_wage_lev</th>
#       <th>zipcode_zipcode_exm</th>
#       <th>zipcode_zipcode_anm</th>
#       <th>zipcode_zipcode_lev</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>a1</td>
#       <td>b1</td>
#       <td>Kevin Smith</td>
#       <td>Mark Levene</td>
#       <td>0.5</td>
#       <td>0.666667</td>
#       <td>0.666667</td>
#       <td>0.888889</td>
#       <td>0</td>
#       <td>...</td>
#       <td>0.327273</td>
#       <td>0</td>
#       <td>0.998994</td>
#       <td>0.75</td>
#       <td>0</td>
#       <td>0.983333</td>
#       <td>0.25</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>a1</td>
#       <td>b2</td>
#       <td>Kevin Smith</td>
#       <td>Bill Bridge</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.888889</td>
#       <td>0</td>
#       <td>...</td>
#       <td>0.145455</td>
#       <td>0</td>
#       <td>0.998492</td>
#       <td>0.75</td>
#       <td>0</td>
#       <td>0.937500</td>
#       <td>0.75</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>a1</td>
#       <td>b6</td>
#       <td>Kevin Smith</td>
#       <td>Michael Brodie</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.888889</td>
#       <td>0</td>
#       <td>...</td>
#       <td>0.181818</td>
#       <td>0</td>
#       <td>0.998994</td>
#       <td>0.75</td>
#       <td>0</td>
#       <td>0.923077</td>
#       <td>0.50</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>a3</td>
#       <td>b1</td>
#       <td>William Bridge</td>
#       <td>Mark Levene</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.888889</td>
#       <td>0</td>
#       <td>...</td>
#       <td>0.127273</td>
#       <td>0</td>
#       <td>0.999497</td>
#       <td>0.75</td>
#       <td>0</td>
#       <td>0.921875</td>
#       <td>0.25</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>a3</td>
#       <td>b2</td>
#       <td>William Bridge</td>
#       <td>Bill Bridge</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.888889</td>
#       <td>0</td>
#       <td>...</td>
#       <td>0.781818</td>
#       <td>1</td>
#       <td>1.000000</td>
#       <td>1.00</td>
#       <td>1</td>
#       <td>1.000000</td>
#       <td>1.00</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>a3</td>
#       <td>b6</td>
#       <td>William Bridge</td>
#       <td>Michael Brodie</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.888889</td>
#       <td>0</td>
#       <td>...</td>
#       <td>0.400000</td>
#       <td>0</td>
#       <td>0.999497</td>
#       <td>0.75</td>
#       <td>0</td>
#       <td>0.984615</td>
#       <td>0.75</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>a2</td>
#       <td>b3</td>
#       <td>Michael Franklin</td>
#       <td>Mike Franklin</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.888889</td>
#       <td>0</td>
#       <td>...</td>
#       <td>0.707692</td>
#       <td>1</td>
#       <td>1.000000</td>
#       <td>1.00</td>
#       <td>1</td>
#       <td>1.000000</td>
#       <td>1.00</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>a2</td>
#       <td>b4</td>
#       <td>Michael Franklin</td>
#       <td>Joseph Kuan</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.888889</td>
#       <td>0</td>
#       <td>...</td>
#       <td>0.181818</td>
#       <td>0</td>
#       <td>0.996982</td>
#       <td>0.75</td>
#       <td>0</td>
#       <td>0.945455</td>
#       <td>0.50</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>a2</td>
#       <td>b5</td>
#       <td>Michael Franklin</td>
#       <td>Alfons Kemper</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.888889</td>
#       <td>0</td>
#       <td>...</td>
#       <td>0.123077</td>
#       <td>0</td>
#       <td>0.997988</td>
#       <td>0.75</td>
#       <td>0</td>
#       <td>0.785714</td>
#       <td>0.25</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>a4</td>
#       <td>b3</td>
#       <td>Binto George</td>
#       <td>Mike Franklin</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.888889</td>
#       <td>0</td>
#       <td>...</td>
#       <td>0.166667</td>
#       <td>0</td>
#       <td>0.999497</td>
#       <td>0.75</td>
#       <td>0</td>
#       <td>0.846154</td>
#       <td>0.50</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>10</td>
#       <td>a4</td>
#       <td>b4</td>
#       <td>Binto George</td>
#       <td>Joseph Kuan</td>
#       <td>0.5</td>
#       <td>0.666667</td>
#       <td>0.666667</td>
#       <td>0.888889</td>
#       <td>0</td>
#       <td>...</td>
#       <td>0.145455</td>
#       <td>0</td>
#       <td>0.997484</td>
#       <td>0.75</td>
#       <td>0</td>
#       <td>0.800000</td>
#       <td>0.25</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>11</td>
#       <td>a4</td>
#       <td>b5</td>
#       <td>Binto George</td>
#       <td>Alfons Kemper</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.888889</td>
#       <td>0</td>
#       <td>...</td>
#       <td>0.150000</td>
#       <td>0</td>
#       <td>0.998490</td>
#       <td>0.75</td>
#       <td>0</td>
#       <td>0.928571</td>
#       <td>0.50</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>12</td>
#       <td>a5</td>
#       <td>b3</td>
#       <td>Alphonse Kemper</td>
#       <td>Mike Franklin</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.888889</td>
#       <td>0</td>
#       <td>...</td>
#       <td>0.153846</td>
#       <td>0</td>
#       <td>0.997988</td>
#       <td>0.75</td>
#       <td>0</td>
#       <td>0.785714</td>
#       <td>0.25</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>13</td>
#       <td>a5</td>
#       <td>b4</td>
#       <td>Alphonse Kemper</td>
#       <td>Joseph Kuan</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.888889</td>
#       <td>0</td>
#       <td>...</td>
#       <td>0.309091</td>
#       <td>0</td>
#       <td>0.998992</td>
#       <td>0.75</td>
#       <td>0</td>
#       <td>0.742857</td>
#       <td>0.50</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>14</td>
#       <td>a5</td>
#       <td>b5</td>
#       <td>Alphonse Kemper</td>
#       <td>Alfons Kemper</td>
#       <td>0.5</td>
#       <td>0.666667</td>
#       <td>0.666667</td>
#       <td>0.888889</td>
#       <td>0</td>
#       <td>...</td>
#       <td>0.723077</td>
#       <td>1</td>
#       <td>1.000000</td>
#       <td>1.00</td>
#       <td>1</td>
#       <td>1.000000</td>
#       <td>1.00</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>15 rows × 27 columns</p>
# </div>
# time: 51 ms
